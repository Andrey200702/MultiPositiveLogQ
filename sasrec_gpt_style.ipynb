# %%
from typing import Dict, List
from collections import defaultdict
import os
from dataclasses import dataclass
import time
import copy

import numpy as np
import polars as pl
import torch
import torch.nn.functional as F
from torch import nn, Tensor
from torch.nn.utils.rnn import pad_sequence
from transformers import get_cosine_schedule_with_warmup
from datasets import load_dataset

# %%
DATA_DIR = "."
TOPK = 100
CORE_MIN_INTERACTIONS_PER_ITEM = 5
TEST_INTERVAL_SECONDS = 7 * 24 * 60 * 60
VALID_INTERVAL_SECONDS = TEST_INTERVAL_SECONDS
TEMPORAL_THRESHOLD = 25_395_195

np.random.seed(42)

ds = load_dataset("/kaggle/input/notebooks/andrewrwerewrew/notebook6738d93a93")

interactions = ds['train'].to_polars()

core_items = (
    interactions
    .group_by("item_id")
    .agg(pl.len().alias("count"))
    .filter(pl.col("count") >= CORE_MIN_INTERACTIONS_PER_ITEM)
    .select("item_id")
)

data = interactions.join(core_items, on="item_id", how="semi")

VALID_START = TEMPORAL_THRESHOLD - VALID_INTERVAL_SECONDS
VALID_END = TEMPORAL_THRESHOLD
TEST_START = TEMPORAL_THRESHOLD
TEST_END = TEMPORAL_THRESHOLD + TEST_INTERVAL_SECONDS

train = data.filter(pl.col("timestamp") < VALID_START)
valid = data.filter(
    (pl.col("timestamp") >= VALID_START) &
    (pl.col("timestamp") < VALID_END)
)
test = data.filter(
    (pl.col("timestamp") >= TEST_START) &
    (pl.col("timestamp") < TEST_END)
)

train_users = train.select("uid").unique()
valid = valid.join(train_users, on="uid", how="semi")

pre_test_users = data.filter(pl.col("timestamp") < TEST_START).select("uid").unique()
test = test.join(pre_test_users, on="uid", how="semi")

valid_targets_df = (
    valid
    .select(["uid", "item_id"])
    .unique(subset=["uid", "item_id"], maintain_order=True)
    .group_by("uid", maintain_order=True)
    .agg(pl.col("item_id"))
)
valid_targets = dict(valid_targets_df.iter_rows())

test_targets_df = (
    test
    .select(["uid", "item_id"])
    .unique(subset=["uid", "item_id"], maintain_order=True)
    .group_by("uid", maintain_order=True)
    .agg(pl.col("item_id"))
)
test_targets = dict(test_targets_df.iter_rows())

# %%
def get_metrics(targets: List[int], candidates: List[int], topk: int) -> Dict[str, float]:
    candidates = candidates[:topk]

    target_set = set(targets)
    denom = min(len(target_set), topk)

    hits = np.array([1.0 if item in target_set else 0.0 for item in candidates], dtype=np.float64)

    hitrate = float(hits.sum() > 0)
    recall = float(hits.sum() / denom)

    discounts = 1.0 / np.log2(np.arange(2, topk + 2, dtype=np.float64))
    dcg = (hits * discounts).sum()
    idcg = discounts[:denom].sum()
    ndcg = dcg / idcg if idcg > 0 else 0.0

    return {"hitrate": hitrate, "recall": recall, "ndcg": ndcg}


def evaluate(
    targets: Dict[int, List[int]],
    candidates: Dict[int, List[int]],
    catalog_size: int,
    topk: int = 100,
) -> Dict[str, float]:
    if len(targets) == 0:
        return {
            "hitrate": 0.0,
            "recall": 0.0,
            "ndcg": 0.0,
            "coverage": 0.0,
        }

    metrics_sum = defaultdict(float)
    recommended_items = set()

    for uid, user_targets in targets.items():
        user_candidates = candidates[uid][:topk]

        m = get_metrics(user_targets, user_candidates, topk=topk)
        for name, value in m.items():
            metrics_sum[name] += value
        recommended_items.update(user_candidates)

    num_users = len(targets)
    out = {name: value / num_users for name, value in metrics_sum.items()}
    out["coverage"] = len(recommended_items) / catalog_size
    return out


def _to_python_float(value):
    if torch.is_tensor(value):
        return float(value.detach().cpu())
    return float(value)


def format_metrics(metrics: Dict[str, float]) -> str:
    return ", ".join(f"{name}={_to_python_float(value):.6f}" for name, value in metrics.items())

# %%
VOCAB_ITEMS = 60_000

item_to_token_id = (
    train
    .group_by("item_id")
    .agg(pl.len().alias("count"))
    .sort(by=["count", "item_id"], descending=[True, False])
    .head(VOCAB_ITEMS)
    .with_row_index(name="token_id")
    .with_columns([
        (pl.col("token_id") + 1).cast(pl.Int64).alias("token_id"),
    ])
    .select(["item_id", "token_id"])
)

# %%
MAX_EVENTS_PER_USER = 100

train_events = train.join(item_to_token_id, on="item_id", how="inner").sort("timestamp").with_columns([pl.col("token_id").cast(pl.Int64)])
train_events = train_events.group_by("uid", maintain_order=True).tail(MAX_EVENTS_PER_USER - 1)
train_histories = pl.concat([
        train_events
        .select("uid")
        .unique(maintain_order=True)
        .with_columns(pl.lit(0, dtype=pl.Int64).alias("token_id")),

        train_events.select([
            pl.col("uid"),
            pl.col("token_id").cast(pl.Int64),
        ]),
    ]).group_by("uid", maintain_order=True).agg(pl.col("token_id"))

# %%
@dataclass
class TrainingBatch:
    inputs: torch.Tensor
    targets: torch.Tensor
    size: int


class TrainingDataset:
    def __init__(
            self,
            df: pl.DataFrame,
            batch_size: int,
            seq_len: int,
            device: str = "cuda",
            chunk_rows: int = 64_000,
            shuffle: bool = True,
            seed: int | None = 42,
            pin_memory: bool = True
    ):
        self.df = df
        self.batch_size = batch_size
        self.seq_len = seq_len
        self.device = device
        self.chunk_rows = chunk_rows
        self.shuffle = shuffle
        self.seed = seed
        self.pin_memory = pin_memory

        self.batch_num_tokens = batch_size * seq_len + 1
        self.total_num_tokens = int(self.df.get_column("token_id").list.len().sum())

    def __len__(self):
        return self.total_num_tokens // self.batch_num_tokens

    def __iter__(self):
        df = self.df
        if self.shuffle:
            df = df.sample(fraction=1.0, shuffle=True, seed=self.seed)

        buf = np.empty(self.batch_num_tokens, dtype=np.int64)
        fill = 0

        for start in range(0, df.height, self.chunk_rows):
            chunk = df.slice(start, self.chunk_rows)
            tokens = chunk.explode("token_id").get_column("token_id").to_numpy()

            pos = 0
            while pos < len(tokens):
                need = self.batch_num_tokens - fill
                take = min(need, len(tokens) - pos)
                buf[fill:fill + take] = tokens[pos:pos + take]
                fill += take
                pos += take

                if fill == self.batch_num_tokens:
                    t = torch.as_tensor(buf.copy(), dtype=torch.long)
                    if self.pin_memory and self.device != "cpu":
                        t = t.pin_memory()
                    t = t.to(self.device, non_blocking=self.pin_memory and self.device != "cpu")

                    inputs = t[:-1].view(self.batch_size, self.seq_len)
                    targets = t[1:].view(self.batch_size, self.seq_len)
                    yield TrainingBatch(inputs, targets, size=inputs.numel())
                    fill = 0

# %%
dataloader = TrainingDataset(train_histories, batch_size=1024, seq_len=100, shuffle=True, device='cuda')

# %%
class CausalSelfAttention(nn.Module):
    def __init__(self, d_model: int, n_heads: int, dropout: float = 0.0):
        super().__init__()
        self.d_model = d_model
        self.n_heads = n_heads
        self.head_dim = d_model // n_heads

        self.qkv = nn.Linear(d_model, 3 * d_model, bias=True)
        self.proj = nn.Linear(d_model, d_model, bias=True)
        self.dropout = dropout

    def forward(self, x: Tensor) -> Tensor:
        B, T, D = x.shape

        qkv = self.qkv(x)
        q, k, v = qkv.chunk(3, dim=-1)

        q = q.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)
        k = k.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)
        v = v.view(B, T, self.n_heads, self.head_dim).transpose(1, 2)

        y = F.scaled_dot_product_attention(
            q, k, v,
            attn_mask=None,
            dropout_p=self.dropout if self.training else 0.0,
            is_causal=True,
        )

        y = y.transpose(1, 2).contiguous().view(B, T, D)
        y = self.proj(y)
        return y


class MLP(nn.Module):
    def __init__(self, d_model: int, dropout: float = 0.0):
        super().__init__()
        self.fc1 = nn.Linear(d_model, 4 * d_model)
        self.fc2 = nn.Linear(4 * d_model, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x: Tensor) -> Tensor:
        x = self.fc1(x)
        x = F.gelu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

class Block(nn.Module):
    def __init__(self, d_model: int, n_heads: int, dropout: float = 0.0):
        super().__init__()
        self.ln1 = nn.LayerNorm(d_model)
        self.attn = CausalSelfAttention(d_model=d_model, n_heads=n_heads, dropout=dropout)
        self.dropout = nn.Dropout(dropout)
        self.ln2 = nn.LayerNorm(d_model)
        self.mlp = MLP(d_model=d_model, dropout=dropout)

    def forward(self, x: Tensor) -> Tensor:
        x = x + self.dropout(self.attn(self.ln1(x)))
        x = x + self.dropout(self.mlp(self.ln2(x)))
        return x


class GPT(nn.Module):
    def __init__(
        self,
        vocab_size: int,
        max_seq_len: int,
        n_layers: int,
        d_model: int,
        n_heads: int,
        dropout: float = 0.0,
    ):
        super().__init__()

        self.max_seq_len = max_seq_len
        self.tok_emb = nn.Embedding(vocab_size, d_model)
        self.pos_emb = nn.Embedding(max_seq_len, d_model)
        self.drop = nn.Dropout(dropout)
        self.blocks = nn.ModuleList([
            Block(d_model=d_model, n_heads=n_heads, dropout=dropout)
            for _ in range(n_layers)
        ])
        self.ln_f = nn.LayerNorm(d_model)

    def forward(self, token_ids: Tensor) -> Tensor:
        B, T = token_ids.shape

        pos = torch.arange(T, device=token_ids.device)
        x = self.tok_emb(token_ids) + self.pos_emb(pos)[None, :, :]
        x = self.drop(x)

        for blk in self.blocks:
            x = blk(x)
            
        x = self.ln_f(x)
        return x

# %%
class Graph(nn.Module):
    def __init__(
        self,
        vocab_size: int,
        max_seq_len: int,
        n_layers: int = 4,
        d_model: int = 256,
        n_heads: int = 4,
        dropout: float = 0.0
    ):
        super().__init__()
        self.gpt = GPT(
            vocab_size=vocab_size,
            max_seq_len=max_seq_len,
            n_layers=n_layers,
            d_model=d_model,
            n_heads=n_heads,
            dropout=dropout,
        )
        self.head = nn.Linear(d_model, vocab_size, bias=False)

    def forward(self, batch: TrainingBatch):
        with torch.autocast(device_type="cuda", dtype=torch.bfloat16):
            x = self.gpt(batch.inputs)
            logits = self.head(x)

        return F.cross_entropy(
            logits.view(-1, logits.size(-1)),
            batch.targets.view(-1)
        )

# %%
def train_loop(
    graph,
    train_dataloader,
    log_dir: str | None = None,
    optimizer=None,
    scheduler=None,
    num_epochs: int = 1,
    grad_accum_steps: int = 1,
    grad_clip: float = 0.0,
    eval_every: int = -1,
    validation_func=None,
    selection_metric: str = "ndcg",
    print_every: int | None = None,
):
    if optimizer is None:
        raise ValueError("optimizer must be provided")

    graph.train()
    tokens_passed = 0
    global_step = 0
    history = []
    base_graph = getattr(graph, "_orig_mod", graph)

    best_metric_value = float("-inf")
    best_state_dict = None
    best_epoch = None

    num_batches = len(train_dataloader)
    if print_every is None:
        print_every = max(1, num_batches // 5)

    for epoch in range(num_epochs):
        train_it = iter(train_dataloader)
        epoch_loss_sum = 0.0
        epoch_tokens = 0
        epoch_start_time = time.time()

        print(f"\nEpoch {epoch + 1}/{num_epochs}")

        for batch_idx in range(num_batches):
            if torch.cuda.is_available():
                torch.cuda.synchronize()
            train_step_t0 = time.time()

            optimizer.zero_grad(set_to_none=True)

            train_loss = 0.0
            curr_tokens = 0

            for _ in range(grad_accum_steps):
                batch = next(train_it)
                curr_tokens += batch.size

                with torch.autocast("cuda", torch.bfloat16):
                    loss = graph(batch)

                loss = loss / grad_accum_steps
                train_loss += float(loss.detach())
                loss.backward()

            if grad_clip > 0.0:
                grad_norm = torch.nn.utils.clip_grad_norm_(graph.parameters(), grad_clip)
                grad_norm_value = float(grad_norm.detach().cpu())
            else:
                grad_norm_value = None

            optimizer.step()
            if scheduler is not None:
                scheduler.step()

            if torch.cuda.is_available():
                torch.cuda.synchronize()
            train_step_t1 = time.time()

            dt = train_step_t1 - train_step_t0
            tokens_passed += curr_tokens
            epoch_tokens += curr_tokens
            epoch_loss_sum += train_loss
            global_step += 1

            if (batch_idx + 1) % print_every == 0 or batch_idx == num_batches - 1:
                lr = optimizer.param_groups[0]["lr"]
                tokens_per_sec = curr_tokens / max(dt, 1e-8)
                msg = (
                    f"  step {batch_idx + 1}/{num_batches} | "
                    f"loss={train_loss:.6f} | lr={lr:.6g} | "
                    f"tokens={curr_tokens} | tok/s={tokens_per_sec:.2f}"
                )
                if grad_norm_value is not None:
                    msg += f" | grad_norm={grad_norm_value:.6f}"
                print(msg)

        epoch_time = time.time() - epoch_start_time
        mean_train_loss = epoch_loss_sum / max(num_batches, 1)
        epoch_record = {
            "epoch": epoch + 1,
            "train_loss": mean_train_loss,
            "tokens_passed": tokens_passed,
            "epoch_tokens": epoch_tokens,
            "epoch_time_sec": epoch_time,
        }

        print(
            f"Epoch {epoch + 1} done | "
            f"train_loss={mean_train_loss:.6f} | "
            f"epoch_tokens={epoch_tokens} | "
            f"epoch_time={epoch_time:.2f}s"
        )

        if validation_func is not None:
            graph.eval()
            with torch.inference_mode():
                valid_metrics = {
                    name: _to_python_float(value)
                    for name, value in validation_func().items()
                }
            graph.train()

            epoch_record["valid_metrics"] = valid_metrics
            print(f"  valid | {format_metrics(valid_metrics)}")

            current_metric_value = valid_metrics.get(selection_metric, float("-inf"))
            if current_metric_value > best_metric_value:
                best_metric_value = current_metric_value
                best_state_dict = {
                    name: tensor.detach().cpu().clone()
                    for name, tensor in base_graph.state_dict().items()
                }
                best_epoch = {
                    "epoch": epoch + 1,
                    "selection_metric": selection_metric,
                    "selection_value": current_metric_value,
                    "valid_metrics": valid_metrics,
                }
                print(
                    f"  new best epoch: {best_epoch['epoch']} | "
                    f"valid/{selection_metric}={best_metric_value:.6f}"
                )

        history.append(epoch_record)

    if best_state_dict is not None:
        base_graph.load_state_dict(best_state_dict)
        print(
            f"\nBest epoch after training: {best_epoch['epoch']} "
            f"by valid/{selection_metric}={best_epoch['selection_value']:.6f}"
        )
        print("Loaded best epoch weights back into the model.")

    return {
        "history": history,
        "best_epoch": best_epoch,
    }

# %%
VOCAB_SIZE = item_to_token_id.height + 1

q_stats = (
    data
    .join(item_to_token_id, on="item_id", how="inner")
    .group_by("token_id")
    .agg(pl.len().alias("cnt"))
    .sort("token_id")
)

item_sampling_probs = torch.zeros(VOCAB_SIZE, dtype=torch.float32)

token_ids = torch.tensor(q_stats["token_id"].to_list(), dtype=torch.long)
cnts = torch.tensor(q_stats["cnt"].to_list(), dtype=torch.float32)

item_sampling_probs[token_ids] = cnts
item_sampling_probs[0] = 0.
item_sampling_probs /= item_sampling_probs.sum()

# %%
MAX_LEN_PER_USER = 100
BOS = 0

def build_eval_histories(
    history_df: pl.DataFrame,
    target_df: pl.DataFrame,
    item_to_token_id: pl.DataFrame,
    max_len_per_user: int = MAX_LEN_PER_USER,
    bos: int = BOS,
) -> pl.DataFrame:
    uid_dtype = history_df.schema["uid"]

    history_events = (
        history_df
        .join(item_to_token_id, on="item_id", how="inner")
        .sort("timestamp")
        .with_columns(pl.col("token_id").cast(pl.Int64))
    )
    token_dtype = history_events.schema["token_id"]

    target_users = target_df.select(pl.col("uid").cast(uid_dtype)).unique()

    history_sequences = (
        history_events
        .select([
            pl.col("uid").cast(uid_dtype),
            pl.col("token_id").cast(token_dtype),
            pl.col("timestamp"),
        ])
        .join(target_users, on="uid", how="semi")
        .sort("timestamp")
        .group_by("uid", maintain_order=True)
        .tail(max_len_per_user - 2)
        .select([
            pl.col("uid").cast(uid_dtype),
            pl.col("token_id").cast(token_dtype),
        ])
    )

    histories = (
        pl.concat([
            target_users.select([
                pl.col("uid").cast(uid_dtype),
                pl.lit(bos).cast(token_dtype).alias("token_id"),
            ]),
            history_sequences.select([
                pl.col("uid").cast(uid_dtype),
                pl.col("token_id").cast(token_dtype),
            ]),
        ])
        .group_by("uid", maintain_order=True)
        .agg(pl.col("token_id"))
    )

    histories = histories.with_columns(length=pl.col("token_id").list.len())
    histories = histories.sort("length", descending=True)
    return histories


valid_histories = build_eval_histories(
    history_df=train,
    target_df=valid,
    item_to_token_id=item_to_token_id,
)

test_histories = build_eval_histories(
    history_df=data.filter(pl.col("timestamp") < TEST_START),
    target_df=test,
    item_to_token_id=item_to_token_id,
)

# %%
@dataclass
class EvalBatch:
    token_ids: torch.Tensor
    lengths: torch.Tensor


class EvalDataset:
    def __init__(
        self,
        df: pl.DataFrame,
        batch_size: int,
        device: str = "cuda",
    ):
        self.df = df
        self.batch_size = batch_size
        self.device = device
        self._tensors = [
            torch.tensor(seq, dtype=torch.long)
            for seq in self.df.get_column("token_id").to_list()
        ]

    def __len__(self):
        return (len(self._tensors) + self.batch_size - 1) // self.batch_size

    def __iter__(self):
        for start in range(0, len(self._tensors), self.batch_size):
            batch_tensors = self._tensors[start:start + self.batch_size]
            lengths = torch.tensor([len(x) for x in batch_tensors], dtype=torch.long)
            token_ids = pad_sequence(batch_tensors, batch_first=True, padding_value=0)
            yield EvalBatch(
                token_ids=token_ids.to(self.device),
                lengths=lengths.to(self.device),
            )


def run_inference(
    graph_module,
    histories: pl.DataFrame,
    item_to_token_id: pl.DataFrame,
    topk: int = 100,
    batch_size: int = 128,
) -> Dict[int, List[int]]:
    if histories.height == 0:
        return {}

    ds = EvalDataset(histories, batch_size=batch_size)
    base_graph = getattr(graph_module, "_orig_mod", graph_module)

    all_candidates = []

    with torch.inference_mode():
        for batch in ds:
            with torch.autocast("cuda", torch.bfloat16):
                hidden_states = base_graph.gpt(batch.token_ids)
                row_idx = torch.arange(batch.token_ids.size(0), device=batch.token_ids.device)
                last_h = hidden_states[row_idx, batch.lengths - 1]
                logits = base_graph.head(last_h)

            logits[:, 0] = -torch.inf
            _, indices = torch.topk(logits, k=topk, dim=-1)
            all_candidates.append(indices.cpu())

    candidates = torch.cat(all_candidates, dim=0)

    candidates_df = pl.DataFrame({
        "uid": histories.get_column("uid"),
        "token_id": candidates.tolist(),
    })

    candidates_df = candidates_df.explode("token_id")
    candidates_df = candidates_df.join(item_to_token_id, on="token_id", how="left")
    candidates_df = candidates_df.group_by("uid", maintain_order=True).agg(pl.col("item_id"))

    return dict(candidates_df.iter_rows())


def evaluate_model(
    graph_module,
    histories: pl.DataFrame,
    targets: Dict[int, List[int]],
    item_to_token_id: pl.DataFrame,
    catalog_size: int,
    topk: int = 100,
    batch_size: int = 128,
) -> Dict[str, float]:
    candidates = run_inference(
        graph_module=graph_module,
        histories=histories,
        item_to_token_id=item_to_token_id,
        topk=topk,
        batch_size=batch_size,
    )
    return evaluate(
        targets=targets,
        candidates=candidates,
        catalog_size=catalog_size,
        topk=topk,
    )

# %%
WARMUP_RATIO = 0.1
NUM_EPOCHES = 50

graph = Graph(
    vocab_size=VOCAB_SIZE,
    max_seq_len=100,
    n_layers=2,
    d_model=128,
    n_heads=4,
    dropout=0.1,
).cuda()

compiled_graph = torch.compile(graph)

optimizer = torch.optim.AdamW(
    compiled_graph.parameters(),
    lr=1e-3,
    weight_decay=1e-4,
    fused=True
)

scheduler = get_cosine_schedule_with_warmup(
    optimizer = optimizer,
    num_warmup_steps = len(dataloader) * WARMUP_RATIO * NUM_EPOCHES,
    num_training_steps = len(dataloader) * NUM_EPOCHES
)

validation_func = lambda: evaluate_model(
    graph_module=compiled_graph,
    histories=valid_histories,
    targets=valid_targets,
    item_to_token_id=item_to_token_id,
    catalog_size=train.get_column("item_id").n_unique(),
    topk=TOPK,
    batch_size=128,
)

train_result = train_loop(
    compiled_graph,
    num_epochs=NUM_EPOCHES,
    train_dataloader=dataloader,
    log_dir='logs/test',
    optimizer=optimizer,
    scheduler = scheduler,
    grad_clip=1.0,
    grad_accum_steps=1,
    eval_every=max(1, len(dataloader)),
    validation_func=validation_func,
    selection_metric="recall",
)

train_result["best_epoch"]
# Out:
# Epoch 1/50
#   step 73/369 | loss=11.143542 | lr=3.95664e-05 | tokens=102400 | tok/s=1635224.92 | grad_norm=0.084566
#   step 146/369 | loss=10.696318 | lr=7.91328e-05 | tokens=102400 | tok/s=1636121.92 | grad_norm=0.223633
#   step 219/369 | loss=10.138192 | lr=0.000118699 | tokens=102400 | tok/s=1635436.62 | grad_norm=0.114908
#   step 292/369 | loss=10.036841 | lr=0.000158266 | tokens=102400 | tok/s=1636333.86 | grad_norm=0.044319
#   step 365/369 | loss=10.040676 | lr=0.000197832 | tokens=102400 | tok/s=1636165.55 | grad_norm=0.038979
#   step 369/369 | loss=9.996641 | lr=0.0002 | tokens=102400 | tok/s=1634049.09 | grad_norm=0.040096
# Epoch 1 done | train_loss=10.519157 | epoch_tokens=37785600 | epoch_time=31.34s
#   valid | hitrate=0.128185, recall=0.036601, ndcg=0.013471, coverage=0.000492
#   new best epoch: 1 | valid/recall=0.036601
#
# Epoch 2/50
#   step 73/369 | loss=10.023923 | lr=0.000239566 | tokens=102400 | tok/s=1634515.48 | grad_norm=0.039072
#   step 146/369 | loss=10.036408 | lr=0.000279133 | tokens=102400 | tok/s=1633464.91 | grad_norm=0.038850
#   step 219/369 | loss=10.011343 | lr=0.000318699 | tokens=102400 | tok/s=1634397.30 | grad_norm=0.038977
#   step 292/369 | loss=10.030045 | lr=0.000358266 | tokens=102400 | tok/s=1636845.23 | grad_norm=0.039036
#   step 365/369 | loss=10.040656 | lr=0.000397832 | tokens=102400 | tok/s=1634291.58 | grad_norm=0.039539
#   step 369/369 | loss=9.996445 | lr=0.0004 | tokens=102400 | tok/s=1634117.47 | grad_norm=0.039425
# Epoch 2 done | train_loss=10.023537 | epoch_tokens=37785600 | epoch_time=23.22s
#   valid | hitrate=0.128262, recall=0.036667, ndcg=0.013584, coverage=0.000247
#   new best epoch: 2 | valid/recall=0.036667
#
# Epoch 3/50
#   step 73/369 | loss=10.024364 | lr=0.000439566 | tokens=102400 | tok/s=1635860.19 | grad_norm=0.038954
#   step 146/369 | loss=10.037964 | lr=0.000479133 | tokens=102400 | tok/s=1635442.85 | grad_norm=0.038158
#   step 219/369 | loss=10.012766 | lr=0.000518699 | tokens=102400 | tok/s=1633141.93 | grad_norm=0.038390
#   step 292/369 | loss=10.031054 | lr=0.000558266 | tokens=102400 | tok/s=1635168.88 | grad_norm=0.037935
#   step 365/369 | loss=10.042202 | lr=0.000597832 | tokens=102400 | tok/s=1636121.92 | grad_norm=0.037457
#   step 369/369 | loss=9.998153 | lr=0.0006 | tokens=102400 | tok/s=1633980.70 | grad_norm=0.037913
# Epoch 3 done | train_loss=10.024747 | epoch_tokens=37785600 | epoch_time=23.51s
#   valid | hitrate=0.127743, recall=0.036443, ndcg=0.013589, coverage=0.000234
#
# Epoch 4/50
#   step 73/369 | loss=10.024637 | lr=0.000639566 | tokens=102400 | tok/s=1632502.55 | grad_norm=0.036985
#   step 146/369 | loss=10.035516 | lr=0.000679133 | tokens=102400 | tok/s=1632459.12 | grad_norm=0.035837
#   step 219/369 | loss=9.948595 | lr=0.000718699 | tokens=102400 | tok/s=1632862.53 | grad_norm=0.066933
#   step 292/369 | loss=9.847609 | lr=0.000758266 | tokens=102400 | tok/s=1633831.52 | grad_norm=0.069546
#   step 365/369 | loss=9.793277 | lr=0.000797832 | tokens=102400 | tok/s=1632701.14 | grad_norm=0.069651
#   step 369/369 | loss=9.729471 | lr=0.0008 | tokens=102400 | tok/s=1633023.95 | grad_norm=0.106993
# Epoch 4 done | train_loss=9.950182 | epoch_tokens=37785600 | epoch_time=23.26s
#   valid | hitrate=0.174927, recall=0.049848, ndcg=0.018212, coverage=0.001244
#   new best epoch: 4 | valid/recall=0.049848
#
# Epoch 5/50
#   step 73/369 | loss=9.687120 | lr=0.000839566 | tokens=102400 | tok/s=1631516.54 | grad_norm=0.112987
#   step 146/369 | loss=9.533235 | lr=0.000879133 | tokens=102400 | tok/s=1632688.73 | grad_norm=0.075056
#   step 219/369 | loss=9.379313 | lr=0.000918699 | tokens=102400 | tok/s=1632874.94 | grad_norm=0.182509
#   step 292/369 | loss=9.292728 | lr=0.000958266 | tokens=102400 | tok/s=1631677.70 | grad_norm=0.150814
#   step 365/369 | loss=9.223144 | lr=0.000997832 | tokens=102400 | tok/s=1632086.92 | grad_norm=0.197854
#   step 369/369 | loss=9.127009 | lr=0.001 | tokens=102400 | tok/s=1630779.36 | grad_norm=0.131882
# Epoch 5 done | train_loss=9.466538 | epoch_tokens=37785600 | epoch_time=23.27s
#   valid | hitrate=0.255901, recall=0.077222, ndcg=0.029675, coverage=0.011336
#   new best epoch: 5 | valid/recall=0.077222
#
# Epoch 6/50
#   step 73/369 | loss=9.079568 | lr=0.000999952 | tokens=102400 | tok/s=1633247.50 | grad_norm=0.135430
#   step 146/369 | loss=9.014850 | lr=0.000999809 | tokens=102400 | tok/s=1634384.86 | grad_norm=0.193330
#   step 219/369 | loss=8.927338 | lr=0.000999571 | tokens=102400 | tok/s=1634733.22 | grad_norm=0.181609
#   step 292/369 | loss=8.873775 | lr=0.000999237 | tokens=102400 | tok/s=1636065.83 | grad_norm=0.201830
#   step 365/369 | loss=8.832474 | lr=0.000998808 | tokens=102400 | tok/s=1634764.34 | grad_norm=0.158483
#   step 369/369 | loss=8.749233 | lr=0.000998782 | tokens=102400 | tok/s=1635007.04 | grad_norm=0.147823
# Epoch 6 done | train_loss=8.969659 | epoch_tokens=37785600 | epoch_time=23.23s
#   valid | hitrate=0.304896, recall=0.096013, ndcg=0.037672, coverage=0.030863
#   new best epoch: 6 | valid/recall=0.096013
#
# Epoch 7/50
#   step 73/369 | loss=8.725280 | lr=0.000998253 | tokens=102400 | tok/s=1634192.09 | grad_norm=0.198228
#   step 146/369 | loss=8.706518 | lr=0.000997628 | tokens=102400 | tok/s=1635087.96 | grad_norm=0.167780
#   step 219/369 | loss=8.631766 | lr=0.000996909 | tokens=102400 | tok/s=1634359.99 | grad_norm=0.155868
#   step 292/369 | loss=8.608150 | lr=0.000996095 | tokens=102400 | tok/s=1634173.43 | grad_norm=0.138322
#   step 365/369 | loss=8.593943 | lr=0.000995187 | tokens=102400 | tok/s=1635100.41 | grad_norm=0.144278
#   step 369/369 | loss=8.505979 | lr=0.000995134 | tokens=102400 | tok/s=1634384.86 | grad_norm=0.138880
# Epoch 7 done | train_loss=8.663461 | epoch_tokens=37785600 | epoch_time=23.23s
#   valid | hitrate=0.335551, recall=0.109338, ndcg=0.043024, coverage=0.053619
#   new best epoch: 7 | valid/recall=0.109338
#
# Epoch 8/50
#   step 73/369 | loss=8.506431 | lr=0.000994126 | tokens=102400 | tok/s=1634322.67 | grad_norm=0.156146
#   step 146/369 | loss=8.515545 | lr=0.000993023 | tokens=102400 | tok/s=1634733.22 | grad_norm=0.150528
#   step 219/369 | loss=8.456771 | lr=0.000991827 | tokens=102400 | tok/s=1633117.09 | grad_norm=0.134679
#   step 292/369 | loss=8.450304 | lr=0.000990536 | tokens=102400 | tok/s=1633539.46 | grad_norm=0.129200
#   step 365/369 | loss=8.441929 | lr=0.000989152 | tokens=102400 | tok/s=1633595.38 | grad_norm=0.127304
#   step 369/369 | loss=8.358993 | lr=0.000989074 | tokens=102400 | tok/s=1632539.79 | grad_norm=0.136277
# Epoch 8 done | train_loss=8.475500 | epoch_tokens=37785600 | epoch_time=23.23s
#   valid | hitrate=0.351820, recall=0.117113, ndcg=0.046490, coverage=0.066779
#   new best epoch: 8 | valid/recall=0.117113
#
# Epoch 9/50
#   step 73/369 | loss=8.372869 | lr=0.000987591 | tokens=102400 | tok/s=1635019.49 | grad_norm=0.139793
#   step 146/369 | loss=8.390183 | lr=0.000986016 | tokens=102400 | tok/s=1634646.12 | grad_norm=0.132393
#   step 219/369 | loss=8.338536 | lr=0.000984348 | tokens=102400 | tok/s=1626185.49 | grad_norm=0.139259
#   step 292/369 | loss=8.340034 | lr=0.000982588 | tokens=102400 | tok/s=1634951.03 | grad_norm=0.134407
#   step 365/369 | loss=8.345056 | lr=0.000980735 | tokens=102400 | tok/s=1634316.45 | grad_norm=0.149454
#   step 369/369 | loss=8.255756 | lr=0.000980631 | tokens=102400 | tok/s=1633253.72 | grad_norm=0.129681
# Epoch 9 done | train_loss=8.353203 | epoch_tokens=37785600 | epoch_time=23.23s
#   valid | hitrate=0.361571, recall=0.121798, ndcg=0.048535, coverage=0.077071
#   new best epoch: 9 | valid/recall=0.121798
#
# Epoch 10/50
#   step 73/369 | loss=8.277929 | lr=0.000978682 | tokens=102400 | tok/s=1633011.53 | grad_norm=0.154579
#   step 146/369 | loss=8.303774 | lr=0.000976641 | tokens=102400 | tok/s=1633607.81 | grad_norm=0.113105
#   step 219/369 | loss=8.257473 | lr=0.00097451 | tokens=102400 | tok/s=1633098.46 | grad_norm=0.125614
#   step 292/369 | loss=8.263133 | lr=0.000972288 | tokens=102400 | tok/s=1632521.17 | grad_norm=0.116731
#   step 365/369 | loss=8.270890 | lr=0.000969976 | tokens=102400 | tok/s=1634739.45 | grad_norm=0.140613
#   step 369/369 | loss=8.180737 | lr=0.000969846 | tokens=102400 | tok/s=1631491.75 | grad_norm=0.152060
# Epoch 10 done | train_loss=8.264995 | epoch_tokens=37785600 | epoch_time=23.27s
#   valid | hitrate=0.369685, recall=0.126074, ndcg=0.050309, coverage=0.084746
#   new best epoch: 10 | valid/recall=0.126074
#
# Epoch 11/50
#   step 73/369 | loss=8.202457 | lr=0.00096744 | tokens=102400 | tok/s=1633539.46 | grad_norm=0.159381
#   step 146/369 | loss=8.236683 | lr=0.000964944 | tokens=102400 | tok/s=1633017.74 | grad_norm=0.114215
#   step 219/369 | loss=8.190493 | lr=0.000962359 | tokens=102400 | tok/s=1632949.44 | grad_norm=0.122573
#   step 292/369 | loss=8.202605 | lr=0.000959687 | tokens=102400 | tok/s=1633545.68 | grad_norm=0.114955
#   step 365/369 | loss=8.206293 | lr=0.000956927 | tokens=102400 | tok/s=1626167.02 | grad_norm=0.136074
#   step 369/369 | loss=8.120423 | lr=0.000956773 | tokens=102400 | tok/s=1632999.11 | grad_norm=0.159208
# Epoch 11 done | train_loss=8.197515 | epoch_tokens=37785600 | epoch_time=23.25s
#   valid | hitrate=0.376163, recall=0.129230, ndcg=0.051544, coverage=0.090144
#   new best epoch: 11 | valid/recall=0.129230
#
# Epoch 12/50
#   step 73/369 | loss=8.150685 | lr=0.00095392 | tokens=102400 | tok/s=1632806.66 | grad_norm=0.139206
#   step 146/369 | loss=8.181538 | lr=0.000950982 | tokens=102400 | tok/s=1632794.25 | grad_norm=0.124025
#   step 219/369 | loss=8.135763 | lr=0.000947957 | tokens=102400 | tok/s=1634503.04 | grad_norm=0.127324
#   step 292/369 | loss=8.147424 | lr=0.000944846 | tokens=102400 | tok/s=1633694.80 | grad_norm=0.103935
#   step 365/369 | loss=8.162079 | lr=0.000941651 | tokens=102400 | tok/s=1634304.02 | grad_norm=0.125673
#   step 369/369 | loss=8.070977 | lr=0.000941474 | tokens=102400 | tok/s=1631690.09 | grad_norm=0.153135
# Epoch 12 done | train_loss=8.143633 | epoch_tokens=37785600 | epoch_time=23.25s
#   valid | hitrate=0.380775, recall=0.131605, ndcg=0.052512, coverage=0.094135
#   new best epoch: 12 | valid/recall=0.131605
#
# Epoch 13/50
#   step 73/369 | loss=8.103054 | lr=0.00093819 | tokens=102400 | tok/s=1631522.74 | grad_norm=0.144543
#   step 146/369 | loss=8.136710 | lr=0.000934822 | tokens=102400 | tok/s=1632018.70 | grad_norm=0.119077
#   step 219/369 | loss=8.094848 | lr=0.000931372 | tokens=102400 | tok/s=1631293.46 | grad_norm=0.122515
#   step 292/369 | loss=8.106140 | lr=0.000927839 | tokens=102400 | tok/s=1632626.67 | grad_norm=0.110689
#   step 365/369 | loss=8.115518 | lr=0.000924224 | tokens=102400 | tok/s=1630488.39 | grad_norm=0.115012
#   step 369/369 | loss=8.030741 | lr=0.000924024 | tokens=102400 | tok/s=1632037.31 | grad_norm=0.152215
# Epoch 13 done | train_loss=8.099095 | epoch_tokens=37785600 | epoch_time=23.28s
#   valid | hitrate=0.384716, recall=0.133669, ndcg=0.053345, coverage=0.097046
#   new best epoch: 13 | valid/recall=0.133669
#
# Epoch 14/50
#   step 73/369 | loss=8.063247 | lr=0.000920324 | tokens=102400 | tok/s=1633589.17 | grad_norm=0.138407
#   step 146/369 | loss=8.100060 | lr=0.000916544 | tokens=102400 | tok/s=1632775.62 | grad_norm=0.109651
#   step 219/369 | loss=8.056318 | lr=0.000912685 | tokens=102400 | tok/s=1633210.24 | grad_norm=0.116092
#   step 292/369 | loss=8.067101 | lr=0.000908747 | tokens=102400 | tok/s=1632347.44 | grad_norm=0.103868
#   step 365/369 | loss=8.084986 | lr=0.000904731 | tokens=102400 | tok/s=1633346.88 | grad_norm=0.132316
#   step 369/369 | loss=7.997381 | lr=0.000904508 | tokens=102400 | tok/s=1633365.52 | grad_norm=0.134048
# Epoch 14 done | train_loss=8.061978 | epoch_tokens=37785600 | epoch_time=23.25s
#   valid | hitrate=0.388305, recall=0.135431, ndcg=0.054001, coverage=0.099072
#   new best epoch: 14 | valid/recall=0.135431
#
# Epoch 15/50
#   step 73/369 | loss=8.031355 | lr=0.000900411 | tokens=102400 | tok/s=1634167.21 | grad_norm=0.126283
#   step 146/369 | loss=8.069384 | lr=0.000896237 | tokens=102400 | tok/s=1632620.46 | grad_norm=0.106533
#   step 219/369 | loss=8.027872 | lr=0.000891988 | tokens=102400 | tok/s=1633570.53 | grad_norm=0.102537
#   step 292/369 | loss=8.042273 | lr=0.000887663 | tokens=102400 | tok/s=1633061.20 | grad_norm=0.116191
#   step 365/369 | loss=8.054793 | lr=0.000883265 | tokens=102400 | tok/s=1632794.25 | grad_norm=0.130575
#   step 369/369 | loss=7.963602 | lr=0.000883022 | tokens=102400 | tok/s=1633446.27 | grad_norm=0.126044
# Epoch 15 done | train_loss=8.030529 | epoch_tokens=37785600 | epoch_time=23.25s
#   valid | hitrate=0.390823, recall=0.136689, ndcg=0.054511, coverage=0.100730
#   new best epoch: 15 | valid/recall=0.136689
#
# Epoch 16/50
#   step 73/369 | loss=8.000484 | lr=0.000878547 | tokens=102400 | tok/s=1632986.69 | grad_norm=0.130140
#   step 146/369 | loss=8.039465 | lr=0.000874 | tokens=102400 | tok/s=1632539.79 | grad_norm=0.115327
#   step 219/369 | loss=7.999840 | lr=0.000869381 | tokens=102400 | tok/s=1634391.08 | grad_norm=0.111219
#   step 292/369 | loss=8.017581 | lr=0.000864691 | tokens=102400 | tok/s=1633303.40 | grad_norm=0.121353
#   step 365/369 | loss=8.031786 | lr=0.000859933 | tokens=102400 | tok/s=1633632.66 | grad_norm=0.126160
#   step 369/369 | loss=7.943055 | lr=0.00085967 | tokens=102400 | tok/s=1634073.95 | grad_norm=0.116817
# Epoch 16 done | train_loss=8.004058 | epoch_tokens=37785600 | epoch_time=23.25s
#   valid | hitrate=0.393207, recall=0.137861, ndcg=0.055020, coverage=0.101761
#   new best epoch: 16 | valid/recall=0.137861
#
# Epoch 17/50
#   step 73/369 | loss=7.976201 | lr=0.000854839 | tokens=102400 | tok/s=1634857.68 | grad_norm=0.126779
#   step 146/369 | loss=8.014273 | lr=0.00084994 | tokens=102400 | tok/s=1634061.52 | grad_norm=0.106720
#   step 219/369 | loss=7.980396 | lr=0.000844974 | tokens=102400 | tok/s=1634434.62 | grad_norm=0.112924
#   step 292/369 | loss=7.993407 | lr=0.000839943 | tokens=102400 | tok/s=1635872.65 | grad_norm=0.115619
#   step 365/369 | loss=8.009644 | lr=0.000834846 | tokens=102400 | tok/s=1635007.04 | grad_norm=0.115362
#   step 369/369 | loss=7.922281 | lr=0.000834565 | tokens=102400 | tok/s=1632639.08 | grad_norm=0.116631
# Epoch 17 done | train_loss=7.981355 | epoch_tokens=37785600 | epoch_time=23.23s
#   valid | hitrate=0.394462, recall=0.138661, ndcg=0.055310, coverage=0.102626
#   new best epoch: 17 | valid/recall=0.138661
#
# Epoch 18/50
#   step 73/369 | loss=7.959310 | lr=0.000829402 | tokens=102400 | tok/s=1635978.58 | grad_norm=0.126016
#   step 146/369 | loss=7.994590 | lr=0.000824175 | tokens=102400 | tok/s=1636146.85 | grad_norm=0.105008
#   step 219/369 | loss=7.961487 | lr=0.000818887 | tokens=102400 | tok/s=1633539.46 | grad_norm=0.107520
#   step 292/369 | loss=7.973998 | lr=0.000813538 | tokens=102400 | tok/s=1635318.31 | grad_norm=0.109892
#   step 365/369 | loss=7.991637 | lr=0.000808129 | tokens=102400 | tok/s=1634241.83 | grad_norm=0.122332
#   step 369/369 | loss=7.902614 | lr=0.000807831 | tokens=102400 | tok/s=1633527.04 | grad_norm=0.115673
# Epoch 18 done | train_loss=7.961892 | epoch_tokens=37785600 | epoch_time=23.24s
#   valid | hitrate=0.396879, recall=0.140031, ndcg=0.055944, coverage=0.103086
#   new best epoch: 18 | valid/recall=0.140031
#
# Epoch 19/50
#   step 73/369 | loss=7.945349 | lr=0.00080236 | tokens=102400 | tok/s=1632974.28 | grad_norm=0.120176
#   step 146/369 | loss=7.977944 | lr=0.000796831 | tokens=102400 | tok/s=1634105.04 | grad_norm=0.106859
#   step 219/369 | loss=7.945697 | lr=0.000791246 | tokens=102400 | tok/s=1633023.95 | grad_norm=0.107731
#   step 292/369 | loss=7.960218 | lr=0.000785605 | tokens=102400 | tok/s=1634036.65 | grad_norm=0.110971
#   step 365/369 | loss=7.978189 | lr=0.00077991 | tokens=102400 | tok/s=1632620.46 | grad_norm=0.115310
#   step 369/369 | loss=7.886865 | lr=0.000779596 | tokens=102400 | tok/s=1633278.56 | grad_norm=0.119878
# Epoch 19 done | train_loss=7.945105 | epoch_tokens=37785600 | epoch_time=23.26s
#   valid | hitrate=0.398071, recall=0.140674, ndcg=0.056164, coverage=0.103528
#   new best epoch: 19 | valid/recall=0.140674
#
# Epoch 20/50
#   step 73/369 | loss=7.926979 | lr=0.000773845 | tokens=102400 | tok/s=1631448.37 | grad_norm=0.108754
#   step 146/369 | loss=7.965610 | lr=0.000768041 | tokens=102400 | tok/s=1633856.39 | grad_norm=0.109530
#   step 219/369 | loss=7.929095 | lr=0.000762186 | tokens=102400 | tok/s=1632750.80 | grad_norm=0.104240
#   step 292/369 | loss=7.939095 | lr=0.000756281 | tokens=102400 | tok/s=1633346.88 | grad_norm=0.108727
#   step 365/369 | loss=7.963928 | lr=0.000750328 | tokens=102400 | tok/s=1632000.10 | grad_norm=0.116139
#   step 369/369 | loss=7.875465 | lr=0.00075 | tokens=102400 | tok/s=1632223.37 | grad_norm=0.118367
# Epoch 20 done | train_loss=7.930089 | epoch_tokens=37785600 | epoch_time=23.26s
#   valid | hitrate=0.400101, recall=0.141725, ndcg=0.056602, coverage=0.103876
#   new best epoch: 20 | valid/recall=0.141725
#
# Epoch 21/50
#   step 73/369 | loss=7.911587 | lr=0.000743996 | tokens=102400 | tok/s=1634671.01 | grad_norm=0.107744
#   step 146/369 | loss=7.952158 | lr=0.000737945 | tokens=102400 | tok/s=1634907.46 | grad_norm=0.103006
#   step 219/369 | loss=7.913741 | lr=0.000731849 | tokens=102400 | tok/s=1634577.69 | grad_norm=0.108105
#   step 292/369 | loss=7.928273 | lr=0.000725709 | tokens=102400 | tok/s=1634596.35 | grad_norm=0.107256
#   step 365/369 | loss=7.953227 | lr=0.000719526 | tokens=102400 | tok/s=1635866.42 | grad_norm=0.121748
#   step 369/369 | loss=7.860002 | lr=0.000719186 | tokens=102400 | tok/s=1636658.10 | grad_norm=0.121694
# Epoch 21 done | train_loss=7.916830 | epoch_tokens=37785600 | epoch_time=23.23s
#   valid | hitrate=0.401362, recall=0.142271, ndcg=0.056819, coverage=0.104170
#   new best epoch: 21 | valid/recall=0.142271
#
# Epoch 22/50
#   step 73/369 | loss=7.900679 | lr=0.000712958 | tokens=102400 | tok/s=1635374.35 | grad_norm=0.107806
#   step 146/369 | loss=7.940105 | lr=0.00070669 | tokens=102400 | tok/s=1637675.32 | grad_norm=0.106782
#   step 219/369 | loss=7.904485 | lr=0.000700383 | tokens=102400 | tok/s=1635835.27 | grad_norm=0.104614
#   step 292/369 | loss=7.920365 | lr=0.000694037 | tokens=102400 | tok/s=1635592.32 | grad_norm=0.106121
#   step 365/369 | loss=7.937045 | lr=0.000687654 | tokens=102400 | tok/s=1634559.03 | grad_norm=0.118924
#   step 369/369 | loss=7.850714 | lr=0.000687303 | tokens=102400 | tok/s=1635031.94 | grad_norm=0.118764
# Epoch 22 done | train_loss=7.905073 | epoch_tokens=37785600 | epoch_time=23.23s
#   valid | hitrate=0.403308, recall=0.143186, ndcg=0.057245, coverage=0.104342
#   new best epoch: 22 | valid/recall=0.143186
#
# Epoch 23/50
#   step 73/369 | loss=7.888548 | lr=0.000680883 | tokens=102400 | tok/s=1635081.73 | grad_norm=0.109308
#   step 146/369 | loss=7.928128 | lr=0.000674428 | tokens=102400 | tok/s=1635611.01 | grad_norm=0.105220
#   step 219/369 | loss=7.891192 | lr=0.00066794 | tokens=102400 | tok/s=1635411.71 | grad_norm=0.108066
#   step 292/369 | loss=7.907787 | lr=0.000661419 | tokens=102400 | tok/s=1636302.69 | grad_norm=0.108188
#   step 365/369 | loss=7.929142 | lr=0.000654868 | tokens=102400 | tok/s=1636209.18 | grad_norm=0.111542
#   step 369/369 | loss=7.837802 | lr=0.000654508 | tokens=102400 | tok/s=1635287.18 | grad_norm=0.106985
# Epoch 23 done | train_loss=7.894239 | epoch_tokens=37785600 | epoch_time=23.22s
#   valid | hitrate=0.403268, recall=0.143370, ndcg=0.057259, coverage=0.104593
#   new best epoch: 23 | valid/recall=0.143370
#
# Epoch 24/50
#   step 73/369 | loss=7.880417 | lr=0.000647926 | tokens=102400 | tok/s=1632378.46 | grad_norm=0.103021
#   step 146/369 | loss=7.919395 | lr=0.000641316 | tokens=102400 | tok/s=1631628.11 | grad_norm=0.109775
#   step 219/369 | loss=7.884590 | lr=0.000634679 | tokens=102400 | tok/s=1632750.80 | grad_norm=0.095531
#   step 292/369 | loss=7.898148 | lr=0.000628016 | tokens=102400 | tok/s=1632465.32 | grad_norm=0.102599
#   step 365/369 | loss=7.921366 | lr=0.000621328 | tokens=102400 | tok/s=1633427.64 | grad_norm=0.117200
#   step 369/369 | loss=7.831727 | lr=0.000620961 | tokens=102400 | tok/s=1632788.04 | grad_norm=0.108218
# Epoch 24 done | train_loss=7.884611 | epoch_tokens=37785600 | epoch_time=23.28s
#   valid | hitrate=0.404736, recall=0.144086, ndcg=0.057595, coverage=0.104759
#   new best epoch: 24 | valid/recall=0.144086
#
# Epoch 25/50
#   step 73/369 | loss=7.869585 | lr=0.000614249 | tokens=102400 | tok/s=1632446.71 | grad_norm=0.101391
#   step 146/369 | loss=7.908098 | lr=0.000607515 | tokens=102400 | tok/s=1632335.03 | grad_norm=0.107049
#   step 219/369 | loss=7.874714 | lr=0.000600761 | tokens=102400 | tok/s=1631975.29 | grad_norm=0.096105
#   step 292/369 | loss=7.891765 | lr=0.000593988 | tokens=102400 | tok/s=1632806.66 | grad_norm=0.099724
#   step 365/369 | loss=7.908983 | lr=0.000587197 | tokens=102400 | tok/s=1633999.35 | grad_norm=0.108994
#   step 369/369 | loss=7.821815 | lr=0.000586824 | tokens=102400 | tok/s=1631962.89 | grad_norm=0.104129
# Epoch 25 done | train_loss=7.875602 | epoch_tokens=37785600 | epoch_time=23.28s
#   valid | hitrate=0.404902, recall=0.144242, ndcg=0.057625, coverage=0.104926
#   new best epoch: 25 | valid/recall=0.144242
#
# Epoch 26/50
#   step 73/369 | loss=7.861055 | lr=0.000580015 | tokens=102400 | tok/s=1634316.45 | grad_norm=0.105636
#   step 146/369 | loss=7.902846 | lr=0.000573191 | tokens=102400 | tok/s=1633775.59 | grad_norm=0.102271
#   step 219/369 | loss=7.866002 | lr=0.000566353 | tokens=102400 | tok/s=1631386.40 | grad_norm=0.094885
#   step 292/369 | loss=7.882105 | lr=0.000559503 | tokens=102400 | tok/s=1631925.69 | grad_norm=0.102606
#   step 365/369 | loss=7.900918 | lr=0.000552641 | tokens=102400 | tok/s=1633421.42 | grad_norm=0.108583
#   step 369/369 | loss=7.812694 | lr=0.000552264 | tokens=102400 | tok/s=1633520.82 | grad_norm=0.099437
# Epoch 26 done | train_loss=7.867317 | epoch_tokens=37785600 | epoch_time=23.26s
#   valid | hitrate=0.406139, recall=0.144743, ndcg=0.057813, coverage=0.105036
#   new best epoch: 26 | valid/recall=0.144743
#
# Epoch 27/50
#   step 73/369 | loss=7.854367 | lr=0.000545392 | tokens=102400 | tok/s=1632974.28 | grad_norm=0.103298
#   step 146/369 | loss=7.896273 | lr=0.00053851 | tokens=102400 | tok/s=1635044.39 | grad_norm=0.100656
#   step 219/369 | loss=7.861051 | lr=0.000531622 | tokens=102400 | tok/s=1633881.25 | grad_norm=0.092517
#   step 292/369 | loss=7.872660 | lr=0.000524727 | tokens=102400 | tok/s=1635299.63 | grad_norm=0.104818
#   step 365/369 | loss=7.896265 | lr=0.000517828 | tokens=102400 | tok/s=1634478.16 | grad_norm=0.110792
#   step 369/369 | loss=7.805638 | lr=0.00051745 | tokens=102400 | tok/s=1631417.39 | grad_norm=0.105797
# Epoch 27 done | train_loss=7.859824 | epoch_tokens=37785600 | epoch_time=23.27s
#   valid | hitrate=0.406769, recall=0.145168, ndcg=0.057926, coverage=0.105130
#   new best epoch: 27 | valid/recall=0.145168
#
# Epoch 28/50
#   step 73/369 | loss=7.847461 | lr=0.000510547 | tokens=102400 | tok/s=1632390.87 | grad_norm=0.104948
#   step 146/369 | loss=7.889022 | lr=0.000503642 | tokens=102400 | tok/s=1632589.43 | grad_norm=0.096486
#   step 219/369 | loss=7.850467 | lr=0.000496736 | tokens=102400 | tok/s=1633210.24 | grad_norm=0.092890
#   step 292/369 | loss=7.867016 | lr=0.000489831 | tokens=102400 | tok/s=1633409.00 | grad_norm=0.102106
#   step 365/369 | loss=7.889436 | lr=0.000482928 | tokens=102400 | tok/s=1628954.77 | grad_norm=0.108604
#   step 369/369 | loss=7.797787 | lr=0.00048255 | tokens=102400 | tok/s=1631882.28 | grad_norm=0.102124
# Epoch 28 done | train_loss=7.852920 | epoch_tokens=37785600 | epoch_time=23.27s
#   valid | hitrate=0.407003, recall=0.145280, ndcg=0.057975, coverage=0.105249
#   new best epoch: 28 | valid/recall=0.145280
#
# Epoch 29/50
#   step 73/369 | loss=7.838776 | lr=0.000475651 | tokens=102400 | tok/s=1632297.81 | grad_norm=0.103702
#   step 146/369 | loss=7.882846 | lr=0.000468756 | tokens=102400 | tok/s=1632254.39 | grad_norm=0.099246
#   step 219/369 | loss=7.845513 | lr=0.000461867 | tokens=102400 | tok/s=1632130.33 | grad_norm=0.093562
#   step 292/369 | loss=7.859971 | lr=0.000454985 | tokens=102400 | tok/s=1637656.59 | grad_norm=0.099116
#   step 365/369 | loss=7.884428 | lr=0.000448112 | tokens=102400 | tok/s=1634347.55 | grad_norm=0.107701
#   step 369/369 | loss=7.794819 | lr=0.000447736 | tokens=102400 | tok/s=1635399.26 | grad_norm=0.106572
# Epoch 29 done | train_loss=7.846364 | epoch_tokens=37785600 | epoch_time=23.26s
#   valid | hitrate=0.408243, recall=0.145908, ndcg=0.058260, coverage=0.105267
#   new best epoch: 29 | valid/recall=0.145908
#
# Epoch 30/50
#   step 73/369 | loss=7.831528 | lr=0.000440873 | tokens=102400 | tok/s=1633576.74 | grad_norm=0.100538
#   step 146/369 | loss=7.874549 | lr=0.000434022 | tokens=102400 | tok/s=1632483.94 | grad_norm=0.094758
#   step 219/369 | loss=7.837866 | lr=0.000427183 | tokens=102400 | tok/s=1632428.10 | grad_norm=0.093145
#   step 292/369 | loss=7.855334 | lr=0.000420358 | tokens=102400 | tok/s=1632254.39 | grad_norm=0.098300
#   step 365/369 | loss=7.875180 | lr=0.000413549 | tokens=102400 | tok/s=1632496.35 | grad_norm=0.104401
#   step 369/369 | loss=7.789168 | lr=0.000413176 | tokens=102400 | tok/s=1632583.22 | grad_norm=0.103497
# Epoch 30 done | train_loss=7.840524 | epoch_tokens=37785600 | epoch_time=23.27s
#   valid | hitrate=0.408439, recall=0.146071, ndcg=0.058318, coverage=0.105334
#   new best epoch: 30 | valid/recall=0.146071
#
# Epoch 31/50
#   step 73/369 | loss=7.823738 | lr=0.000406384 | tokens=102400 | tok/s=1632291.61 | grad_norm=0.096013
#   step 146/369 | loss=7.867903 | lr=0.000399609 | tokens=102400 | tok/s=1633570.53 | grad_norm=0.093261
#   step 219/369 | loss=7.834262 | lr=0.000392854 | tokens=102400 | tok/s=1632955.65 | grad_norm=0.096514
#   step 292/369 | loss=7.849189 | lr=0.000386119 | tokens=102400 | tok/s=1632943.23 | grad_norm=0.094454
#   step 365/369 | loss=7.870387 | lr=0.000379406 | tokens=102400 | tok/s=1635131.53 | grad_norm=0.098976
#   step 369/369 | loss=7.778442 | lr=0.000379039 | tokens=102400 | tok/s=1633725.87 | grad_norm=0.102982
# Epoch 31 done | train_loss=7.834999 | epoch_tokens=37785600 | epoch_time=23.26s
#   valid | hitrate=0.408627, recall=0.146299, ndcg=0.058404, coverage=0.105420
#   new best epoch: 31 | valid/recall=0.146299
#
# Epoch 32/50
#   step 73/369 | loss=7.821578 | lr=0.00037235 | tokens=102400 | tok/s=1633607.81 | grad_norm=0.097076
#   step 146/369 | loss=7.866229 | lr=0.000365686 | tokens=102400 | tok/s=1633657.52 | grad_norm=0.094494
#   step 219/369 | loss=7.828649 | lr=0.000359047 | tokens=102400 | tok/s=1632639.08 | grad_norm=0.099348
#   step 292/369 | loss=7.846572 | lr=0.000352435 | tokens=102400 | tok/s=1633682.37 | grad_norm=0.096093
#   step 365/369 | loss=7.868896 | lr=0.000345851 | tokens=102400 | tok/s=1633067.41 | grad_norm=0.101326
#   step 369/369 | loss=7.775795 | lr=0.000345492 | tokens=102400 | tok/s=1632980.49 | grad_norm=0.106807
# Epoch 32 done | train_loss=7.829965 | epoch_tokens=37785600 | epoch_time=23.26s
#   valid | hitrate=0.409168, recall=0.146536, ndcg=0.058435, coverage=0.105496
#   new best epoch: 32 | valid/recall=0.146536
#
# Epoch 33/50
#   step 73/369 | loss=7.820359 | lr=0.000338939 | tokens=102400 | tok/s=1634434.62 | grad_norm=0.094318
#   step 146/369 | loss=7.858865 | lr=0.000332417 | tokens=102400 | tok/s=1633657.52 | grad_norm=0.091189
#   step 219/369 | loss=7.824312 | lr=0.000325927 | tokens=102400 | tok/s=1631987.69 | grad_norm=0.093374
#   step 292/369 | loss=7.841870 | lr=0.00031947 | tokens=102400 | tok/s=1633732.09 | grad_norm=0.098308
#   step 365/369 | loss=7.863491 | lr=0.000313048 | tokens=102400 | tok/s=1633259.93 | grad_norm=0.097174
#   step 369/369 | loss=7.772080 | lr=0.000312697 | tokens=102400 | tok/s=1632657.70 | grad_norm=0.105426
# Epoch 33 done | train_loss=7.825395 | epoch_tokens=37785600 | epoch_time=23.26s
#   valid | hitrate=0.409740, recall=0.146776, ndcg=0.058634, coverage=0.105579
#   new best epoch: 33 | valid/recall=0.146776
#
# Epoch 34/50
#   step 73/369 | loss=7.812242 | lr=0.000306312 | tokens=102400 | tok/s=1635679.52 | grad_norm=0.095802
#   step 146/369 | loss=7.858525 | lr=0.000299964 | tokens=102400 | tok/s=1634807.89 | grad_norm=0.092877
#   step 219/369 | loss=7.820703 | lr=0.000293655 | tokens=102400 | tok/s=1636308.92 | grad_norm=0.093292
#   step 292/369 | loss=7.836183 | lr=0.000287384 | tokens=102400 | tok/s=1635617.23 | grad_norm=0.097272
#   step 365/369 | loss=7.858558 | lr=0.000281155 | tokens=102400 | tok/s=1636421.14 | grad_norm=0.097738
#   step 369/369 | loss=7.767082 | lr=0.000280814 | tokens=102400 | tok/s=1635069.28 | grad_norm=0.109191
# Epoch 34 done | train_loss=7.821109 | epoch_tokens=37785600 | epoch_time=23.22s
#   valid | hitrate=0.410477, recall=0.147227, ndcg=0.058880, coverage=0.105604
#   new best epoch: 34 | valid/recall=0.147227
#
# Epoch 35/50
#   step 73/369 | loss=7.808248 | lr=0.000274629 | tokens=102400 | tok/s=1633172.98 | grad_norm=0.095133
#   step 146/369 | loss=7.854178 | lr=0.000268486 | tokens=102400 | tok/s=1633502.19 | grad_norm=0.090959
#   step 219/369 | loss=7.818620 | lr=0.000262388 | tokens=102400 | tok/s=1633402.79 | grad_norm=0.094608
#   step 292/369 | loss=7.830863 | lr=0.000256334 | tokens=102400 | tok/s=1632999.11 | grad_norm=0.096165
#   step 365/369 | loss=7.853385 | lr=0.000250328 | tokens=102400 | tok/s=1632632.87 | grad_norm=0.092888
#   step 369/369 | loss=7.761986 | lr=0.00025 | tokens=102400 | tok/s=1631745.88 | grad_norm=0.100147
# Epoch 35 done | train_loss=7.817069 | epoch_tokens=37785600 | epoch_time=23.26s
#   valid | hitrate=0.410159, recall=0.147144, ndcg=0.058763, coverage=0.105645
#
# Epoch 36/50
#   step 73/369 | loss=7.803616 | lr=0.000244044 | tokens=102400 | tok/s=1634845.23 | grad_norm=0.091810
#   step 146/369 | loss=7.849678 | lr=0.000238136 | tokens=102400 | tok/s=1635735.59 | grad_norm=0.090093
#   step 219/369 | loss=7.813277 | lr=0.000232278 | tokens=102400 | tok/s=1633738.30 | grad_norm=0.092852
#   step 292/369 | loss=7.829453 | lr=0.000226472 | tokens=102400 | tok/s=1635106.63 | grad_norm=0.092891
#   step 365/369 | loss=7.850721 | lr=0.000220717 | tokens=102400 | tok/s=1632273.00 | grad_norm=0.094286
#   step 369/369 | loss=7.759725 | lr=0.000220404 | tokens=102400 | tok/s=1632192.36 | grad_norm=0.099967
# Epoch 36 done | train_loss=7.813339 | epoch_tokens=37785600 | epoch_time=23.24s
#   valid | hitrate=0.410164, recall=0.147031, ndcg=0.058696, coverage=0.105664
#
# Epoch 37/50
#   step 73/369 | loss=7.804235 | lr=0.000214705 | tokens=102400 | tok/s=1632273.00 | grad_norm=0.091475
#   step 146/369 | loss=7.847308 | lr=0.000209062 | tokens=102400 | tok/s=1634583.91 | grad_norm=0.093071
#   step 219/369 | loss=7.809841 | lr=0.000203473 | tokens=102400 | tok/s=1633346.88 | grad_norm=0.092364
#   step 292/369 | loss=7.824725 | lr=0.000197942 | tokens=102400 | tok/s=1632316.42 | grad_norm=0.089446
#   step 365/369 | loss=7.847386 | lr=0.000192468 | tokens=102400 | tok/s=1632707.35 | grad_norm=0.093381
#   step 369/369 | loss=7.755470 | lr=0.000192169 | tokens=102400 | tok/s=1631126.19 | grad_norm=0.095755
# Epoch 37 done | train_loss=7.810144 | epoch_tokens=37785600 | epoch_time=23.28s
#   valid | hitrate=0.410630, recall=0.147290, ndcg=0.058841, coverage=0.105652
#   new best epoch: 37 | valid/recall=0.147290
#
# Epoch 38/50
#   step 73/369 | loss=7.798125 | lr=0.000186757 | tokens=102400 | tok/s=1632291.61 | grad_norm=0.093071
#   step 146/369 | loss=7.841325 | lr=0.000181405 | tokens=102400 | tok/s=1631243.89 | grad_norm=0.088114
#   step 219/369 | loss=7.809401 | lr=0.000176113 | tokens=102400 | tok/s=1633669.95 | grad_norm=0.093673
#   step 292/369 | loss=7.823049 | lr=0.000170883 | tokens=102400 | tok/s=1632632.87 | grad_norm=0.089279
#   step 365/369 | loss=7.846390 | lr=0.000165716 | tokens=102400 | tok/s=1631919.48 | grad_norm=0.089922
#   step 369/369 | loss=7.753201 | lr=0.000165435 | tokens=102400 | tok/s=1631597.11 | grad_norm=0.093660
# Epoch 38 done | train_loss=7.807208 | epoch_tokens=37785600 | epoch_time=23.27s
#   valid | hitrate=0.411351, recall=0.147691, ndcg=0.058952, coverage=0.105688
#   new best epoch: 38 | valid/recall=0.147691
#
# Epoch 39/50
#   step 73/369 | loss=7.795091 | lr=0.000160335 | tokens=102400 | tok/s=1630977.53 | grad_norm=0.095023
#   step 146/369 | loss=7.841685 | lr=0.0001553 | tokens=102400 | tok/s=1632260.59 | grad_norm=0.088189
#   step 219/369 | loss=7.804436 | lr=0.000150331 | tokens=102400 | tok/s=1631064.24 | grad_norm=0.092950
#   step 292/369 | loss=7.818871 | lr=0.000145428 | tokens=102400 | tok/s=1632105.53 | grad_norm=0.093830
#   step 365/369 | loss=7.839993 | lr=0.000140593 | tokens=102400 | tok/s=1633322.04 | grad_norm=0.092535
#   step 369/369 | loss=7.752851 | lr=0.00014033 | tokens=102400 | tok/s=1631398.80 | grad_norm=0.094125
# Epoch 39 done | train_loss=7.804282 | epoch_tokens=37785600 | epoch_time=23.27s
#   valid | hitrate=0.410713, recall=0.147320, ndcg=0.058816, coverage=0.105721
#
# Epoch 40/50
#   step 73/369 | loss=7.793562 | lr=0.000135567 | tokens=102400 | tok/s=1632297.81 | grad_norm=0.097549
#   step 146/369 | loss=7.839585 | lr=0.000130874 | tokens=102400 | tok/s=1632310.22 | grad_norm=0.087842
#   step 219/369 | loss=7.800951 | lr=0.000126252 | tokens=102400 | tok/s=1632297.81 | grad_norm=0.094859
#   step 292/369 | loss=7.817379 | lr=0.0001217 | tokens=102400 | tok/s=1634664.78 | grad_norm=0.092470
#   step 365/369 | loss=7.840392 | lr=0.000117221 | tokens=102400 | tok/s=1631931.89 | grad_norm=0.091063
#   step 369/369 | loss=7.750132 | lr=0.000116978 | tokens=102400 | tok/s=1632545.99 | grad_norm=0.092934
# Epoch 40 done | train_loss=7.801951 | epoch_tokens=37785600 | epoch_time=23.27s
#   valid | hitrate=0.410764, recall=0.147301, ndcg=0.058840, coverage=0.105732
#
# Epoch 41/50
#   step 73/369 | loss=7.789576 | lr=0.000112576 | tokens=102400 | tok/s=1633204.03 | grad_norm=0.095848
#   step 146/369 | loss=7.835075 | lr=0.000108247 | tokens=102400 | tok/s=1633495.97 | grad_norm=0.089424
#   step 219/369 | loss=7.801872 | lr=0.000103994 | tokens=102400 | tok/s=1631776.88 | grad_norm=0.093323
#   step 292/369 | loss=7.817105 | lr=9.98157e-05 | tokens=102400 | tok/s=1632657.70 | grad_norm=0.095550
#   step 365/369 | loss=7.836256 | lr=9.5714e-05 | tokens=102400 | tok/s=1632955.65 | grad_norm=0.092823
#   step 369/369 | loss=7.744792 | lr=9.54915e-05 | tokens=102400 | tok/s=1631795.48 | grad_norm=0.090174
# Epoch 41 done | train_loss=7.799805 | epoch_tokens=37785600 | epoch_time=23.27s
#   valid | hitrate=0.411323, recall=0.147625, ndcg=0.058995, coverage=0.105730
#
# Epoch 42/50
#   step 73/369 | loss=7.789588 | lr=9.14712e-05 | tokens=102400 | tok/s=1633582.95 | grad_norm=0.091657
#   step 146/369 | loss=7.833874 | lr=8.75288e-05 | tokens=102400 | tok/s=1633284.77 | grad_norm=0.089640
#   step 219/369 | loss=7.799180 | lr=8.36651e-05 | tokens=102400 | tok/s=1633788.02 | grad_norm=0.091168
#   step 292/369 | loss=7.812173 | lr=7.98808e-05 | tokens=102400 | tok/s=1633999.35 | grad_norm=0.093280
#   step 365/369 | loss=7.837973 | lr=7.61766e-05 | tokens=102400 | tok/s=1634154.78 | grad_norm=0.092638
#   step 369/369 | loss=7.746305 | lr=7.5976e-05 | tokens=102400 | tok/s=1633707.23 | grad_norm=0.091742
# Epoch 42 done | train_loss=7.797711 | epoch_tokens=37785600 | epoch_time=23.27s
#   valid | hitrate=0.411280, recall=0.147686, ndcg=0.058980, coverage=0.105748
#
# Epoch 43/50
#   step 73/369 | loss=7.786541 | lr=7.23571e-05 | tokens=102400 | tok/s=1634397.30 | grad_norm=0.091503
#   step 146/369 | loss=7.834955 | lr=6.88198e-05 | tokens=102400 | tok/s=1633862.60 | grad_norm=0.088119
#   step 219/369 | loss=7.798627 | lr=6.53647e-05 | tokens=102400 | tok/s=1631733.49 | grad_norm=0.090651
#   step 292/369 | loss=7.813555 | lr=6.19926e-05 | tokens=102400 | tok/s=1634042.87 | grad_norm=0.091430
#   step 365/369 | loss=7.833889 | lr=5.8704e-05 | tokens=102400 | tok/s=1633117.09 | grad_norm=0.090000
#   step 369/369 | loss=7.745099 | lr=5.85262e-05 | tokens=102400 | tok/s=1632676.32 | grad_norm=0.090234
# Epoch 43 done | train_loss=7.796044 | epoch_tokens=37785600 | epoch_time=23.26s
#   valid | hitrate=0.411570, recall=0.147784, ndcg=0.059022, coverage=0.105735
#   new best epoch: 43 | valid/recall=0.147784
#
# Epoch 44/50
#   step 73/369 | loss=7.782052 | lr=5.53264e-05 | tokens=102400 | tok/s=1635511.35 | grad_norm=0.089407
#   step 146/369 | loss=7.829978 | lr=5.22114e-05 | tokens=102400 | tok/s=1635835.27 | grad_norm=0.086507
#   step 219/369 | loss=7.794242 | lr=4.91819e-05 | tokens=102400 | tok/s=1635237.37 | grad_norm=0.090084
#   step 292/369 | loss=7.809257 | lr=4.62383e-05 | tokens=102400 | tok/s=1635486.44 | grad_norm=0.091543
#   step 365/369 | loss=7.833672 | lr=4.33813e-05 | tokens=102400 | tok/s=1634571.47 | grad_norm=0.091604
#   step 369/369 | loss=7.741197 | lr=4.32273e-05 | tokens=102400 | tok/s=1635330.76 | grad_norm=0.092580
# Epoch 44 done | train_loss=7.794852 | epoch_tokens=37785600 | epoch_time=23.23s
#   valid | hitrate=0.411687, recall=0.147846, ndcg=0.059087, coverage=0.105759
#   new best epoch: 44 | valid/recall=0.147846
#
# Epoch 45/50
#   step 73/369 | loss=7.785560 | lr=4.04621e-05 | tokens=102400 | tok/s=1632980.49 | grad_norm=0.090461
#   step 146/369 | loss=7.827777 | lr=3.77847e-05 | tokens=102400 | tok/s=1634702.12 | grad_norm=0.086284
#   step 219/369 | loss=7.792309 | lr=3.51954e-05 | tokens=102400 | tok/s=1633172.98 | grad_norm=0.087409
#   step 292/369 | loss=7.811927 | lr=3.26947e-05 | tokens=102400 | tok/s=1633955.84 | grad_norm=0.087647
#   step 365/369 | loss=7.832513 | lr=3.02832e-05 | tokens=102400 | tok/s=1631299.65 | grad_norm=0.088763
#   step 369/369 | loss=7.743244 | lr=3.01537e-05 | tokens=102400 | tok/s=1631869.88 | grad_norm=0.091239
# Epoch 45 done | train_loss=7.793590 | epoch_tokens=37785600 | epoch_time=23.27s
#   valid | hitrate=0.411786, recall=0.147833, ndcg=0.059096, coverage=0.105769
#
# Epoch 46/50
#   step 73/369 | loss=7.782485 | lr=2.78367e-05 | tokens=102400 | tok/s=1634359.99 | grad_norm=0.088697
#   step 146/369 | loss=7.826850 | lr=2.56098e-05 | tokens=102400 | tok/s=1632769.42 | grad_norm=0.084612
#   step 219/369 | loss=7.790740 | lr=2.34734e-05 | tokens=102400 | tok/s=1632421.89 | grad_norm=0.086804
#   step 292/369 | loss=7.805871 | lr=2.14278e-05 | tokens=102400 | tok/s=1632558.40 | grad_norm=0.089221
#   step 365/369 | loss=7.830949 | lr=1.94736e-05 | tokens=102400 | tok/s=1634185.87 | grad_norm=0.088371
#   step 369/369 | loss=7.744008 | lr=1.93692e-05 | tokens=102400 | tok/s=1631367.81 | grad_norm=0.091146
# Epoch 46 done | train_loss=7.792636 | epoch_tokens=37785600 | epoch_time=23.27s
#   valid | hitrate=0.411819, recall=0.147802, ndcg=0.059067, coverage=0.105773
#
# Epoch 47/50
#   step 73/369 | loss=7.785102 | lr=1.75116e-05 | tokens=102400 | tok/s=1631758.28 | grad_norm=0.089280
#   step 146/369 | loss=7.827341 | lr=1.57461e-05 | tokens=102400 | tok/s=1632161.35 | grad_norm=0.084491
#   step 219/369 | loss=7.791853 | lr=1.40729e-05 | tokens=102400 | tok/s=1632589.43 | grad_norm=0.087478
#   step 292/369 | loss=7.808969 | lr=1.24925e-05 | tokens=102400 | tok/s=1634080.17 | grad_norm=0.088337
#   step 365/369 | loss=7.831456 | lr=1.1005e-05 | tokens=102400 | tok/s=1632291.61 | grad_norm=0.089292
#   step 369/369 | loss=7.740337 | lr=1.09262e-05 | tokens=102400 | tok/s=1632601.84 | grad_norm=0.092252
# Epoch 47 done | train_loss=7.791781 | epoch_tokens=37785600 | epoch_time=23.28s
#   valid | hitrate=0.411867, recall=0.147831, ndcg=0.059075, coverage=0.105766
#
# Epoch 48/50
#   step 73/369 | loss=7.780841 | lr=9.53713e-06 | tokens=102400 | tok/s=1633906.11 | grad_norm=0.086012
#   step 146/369 | loss=7.825461 | lr=8.24161e-06 | tokens=102400 | tok/s=1632701.14 | grad_norm=0.086470
#   step 219/369 | loss=7.793589 | lr=7.03989e-06 | tokens=102400 | tok/s=1633688.59 | grad_norm=0.086153
#   step 292/369 | loss=7.806863 | lr=5.93221e-06 | tokens=102400 | tok/s=1632719.76 | grad_norm=0.088962
#   step 365/369 | loss=7.831162 | lr=4.91877e-06 | tokens=102400 | tok/s=1632192.36 | grad_norm=0.087118
#   step 369/369 | loss=7.739161 | lr=4.86597e-06 | tokens=102400 | tok/s=1630853.67 | grad_norm=0.090034
# Epoch 48 done | train_loss=7.791283 | epoch_tokens=37785600 | epoch_time=23.28s
#   valid | hitrate=0.411875, recall=0.147891, ndcg=0.059104, coverage=0.105769
#   new best epoch: 48 | valid/recall=0.147891
#
# Epoch 49/50
#   step 73/369 | loss=7.782072 | lr=3.95214e-06 | tokens=102400 | tok/s=1632409.48 | grad_norm=0.087971
#   step 146/369 | loss=7.824922 | lr=3.13293e-06 | tokens=102400 | tok/s=1634764.34 | grad_norm=0.085287
#   step 219/369 | loss=7.790037 | lr=2.40851e-06 | tokens=102400 | tok/s=1631181.94 | grad_norm=0.086221
#   step 292/369 | loss=7.808036 | lr=1.77899e-06 | tokens=102400 | tok/s=1632279.20 | grad_norm=0.087285
#   step 365/369 | loss=7.829501 | lr=1.24451e-06 | tokens=102400 | tok/s=1631485.55 | grad_norm=0.088724
#   step 369/369 | loss=7.741053 | lr=1.21797e-06 | tokens=102400 | tok/s=1633377.94 | grad_norm=0.092101
# Epoch 49 done | train_loss=7.790886 | epoch_tokens=37785600 | epoch_time=23.26s
#   valid | hitrate=0.412020, recall=0.147976, ndcg=0.059149, coverage=0.105771
#   new best epoch: 49 | valid/recall=0.147976
#
# Epoch 50/50
#   step 73/369 | loss=7.779813 | lr=7.83848e-07 | tokens=102400 | tok/s=1632812.87 | grad_norm=0.087929
#   step 146/369 | loss=7.828513 | lr=4.44946e-07 | tokens=102400 | tok/s=1632093.12 | grad_norm=0.083831
#   step 219/369 | loss=7.789094 | lr=2.01333e-07 | tokens=102400 | tok/s=1632968.07 | grad_norm=0.086600
#   step 292/369 | loss=7.806012 | lr=5.30562e-08 | tokens=102400 | tok/s=1633962.05 | grad_norm=0.088376
#   step 365/369 | loss=7.828095 | lr=1.4318e-10 | tokens=102400 | tok/s=1632366.05 | grad_norm=0.088190
#   step 369/369 | loss=7.740233 | lr=0 | tokens=102400 | tok/s=1631652.90 | grad_norm=0.090188
# Epoch 50 done | train_loss=7.790509 | epoch_tokens=37785600 | epoch_time=23.26s
#   valid | hitrate=0.412058, recall=0.147993, ndcg=0.059150, coverage=0.105769
#   new best epoch: 50 | valid/recall=0.147993
#
# Best epoch after training: 50 by valid/recall=0.147993
# Loaded best epoch weights back into the model.
# {'epoch': 50,
#  'selection_metric': 'recall',
#  'selection_value': 0.14799314887877402,
#  'valid_metrics': {'hitrate': 0.4120576964127794,
#   'recall': 0.14799314887877402,
#   'ndcg': 0.05914984384795485,
#   'coverage': 0.10576917958082015}}

# %%
history_df = pl.DataFrame([
    {
        "epoch": row["epoch"],
        "train_loss": row["train_loss"],
        "epoch_tokens": row["epoch_tokens"],
        "epoch_time_sec": row["epoch_time_sec"],
        **(row.get("valid_metrics") or {}),
    }
    for row in train_result["history"]
])

history_df
# Out:
# shape: (50, 8)
# ┌───────┬────────────┬──────────────┬────────────────┬──────────┬──────────┬──────────┬──────────┐
# │ epoch ┆ train_loss ┆ epoch_tokens ┆ epoch_time_sec ┆ hitrate  ┆ recall   ┆ ndcg     ┆ coverage │
# │ ---   ┆ ---        ┆ ---          ┆ ---            ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ i64   ┆ f64        ┆ i64          ┆ f64            ┆ f64      ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════╪════════════╪══════════════╪════════════════╪══════════╪══════════╪══════════╪══════════╡
# │ 1     ┆ 10.519157  ┆ 37785600     ┆ 31.344779      ┆ 0.128185 ┆ 0.036601 ┆ 0.013471 ┆ 0.000492 │
# │ 2     ┆ 10.023537  ┆ 37785600     ┆ 23.224638      ┆ 0.128262 ┆ 0.036667 ┆ 0.013584 ┆ 0.000247 │
# │ 3     ┆ 10.024747  ┆ 37785600     ┆ 23.514791      ┆ 0.127743 ┆ 0.036443 ┆ 0.013589 ┆ 0.000234 │
# │ 4     ┆ 9.950182   ┆ 37785600     ┆ 23.257583      ┆ 0.174927 ┆ 0.049848 ┆ 0.018212 ┆ 0.001244 │
# │ 5     ┆ 9.466538   ┆ 37785600     ┆ 23.272098      ┆ 0.255901 ┆ 0.077222 ┆ 0.029675 ┆ 0.011336 │
# │ …     ┆ …          ┆ …            ┆ …              ┆ …        ┆ …        ┆ …        ┆ …        │
# │ 46    ┆ 7.792636   ┆ 37785600     ┆ 23.274129      ┆ 0.411819 ┆ 0.147802 ┆ 0.059067 ┆ 0.105773 │
# │ 47    ┆ 7.791781   ┆ 37785600     ┆ 23.27525       ┆ 0.411867 ┆ 0.147831 ┆ 0.059075 ┆ 0.105766 │
# │ 48    ┆ 7.791283   ┆ 37785600     ┆ 23.277105      ┆ 0.411875 ┆ 0.147891 ┆ 0.059104 ┆ 0.105769 │
# │ 49    ┆ 7.790886   ┆ 37785600     ┆ 23.263988      ┆ 0.41202  ┆ 0.147976 ┆ 0.059149 ┆ 0.105771 │
# │ 50    ┆ 7.790509   ┆ 37785600     ┆ 23.264227      ┆ 0.412058 ┆ 0.147993 ┆ 0.05915  ┆ 0.105769 │
# └───────┴────────────┴──────────────┴────────────────┴──────────┴──────────┴──────────┴──────────┘

# %%
history_df['recall'].to_pandas().plot()
# Out:
# <Axes: >

# %%
compiled_graph.eval()
valid_metrics = evaluate_model(
    graph_module=compiled_graph,
    histories=valid_histories,
    targets=valid_targets,
    item_to_token_id=item_to_token_id,
    catalog_size=train.get_column("item_id").n_unique(),
    topk=TOPK,
    batch_size=128,
)

valid_metrics
# Out:
# {'hitrate': 0.4120576964127794,
#  'recall': 0.14799314887877402,
#  'ndcg': np.float64(0.05914984384795485),
#  'coverage': 0.10576917958082015}

# %%
test_metrics = evaluate_model(
    graph_module=compiled_graph,
    histories=test_histories,
    targets=test_targets,
    item_to_token_id=item_to_token_id,
    catalog_size=train.get_column("item_id").n_unique(),
    topk=TOPK,
    batch_size=128,
)

test_metrics
# Out:
# {'hitrate': 0.3857141377953571,
#  'recall': 0.13354941675957024,
#  'ndcg': np.float64(0.052191402499844365),
#  'coverage': 0.10573901254416365}
